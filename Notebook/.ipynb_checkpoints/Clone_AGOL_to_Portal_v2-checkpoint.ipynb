# %% [markdown]
# ## How to Clone from AGOL to Portal
#
# Procedure:
#
# ##### Clone individual feature services
# 1. Sign in AGOL (**Source)
# 2. Sign in Portal for ArcGIS (**Target)
# 3. Create helper functions
# 4. Extract only hosted feature services from the **source
# 5. Clone the feature services from source to **target
# 6. Check the feature services cloned in the **target
#
# ##### Clone Web Maps and Operations Dashboard and associated hosted feature services
# ##### Note that non-hosted feature services cannot be cloned.
#
# Reference: https://developers.arcgis.com/python/guide/cloning-content/
# https://support.esri.com/en/technical-article/000018924
# https://developers.arcgis.com/python/guide/accessing-and-creating-content/

# %%
from pathlib import Path
import sys

from arcgis.gis import GIS, Item
from arcgis.env import active_gis
from arcgis.features import FeatureLayerCollection
from arcgis.mapping import WebMap

# %%
# 1. Sign in Source (AGOL)
# GIS("https://railway-sector.maps.arcgis.com", "matsuzakieijinscrex", "timberland12345", verity_cert=False)
source = GIS("https://railway-sector.maps.arcgis.com", "matsuzakieijinscrex", "timberland12345", verity_cert=False)

# %%
# Sign in Target (Portal)
target = GIS("https://mmspgc-gis.mmspgc.local/portal", "matsuzakieiji", "timberland12345", verify_cert = False)

# %%
active_gis = source

# %%
def get_user_items(user, active_gis):
    user_inventory = {}
    user_items = active_gis.content.search(query=f"* AND owner:{user.username}", 
                                           max_items=500)
    for item in user_items:
        if item.type not in user_inventory:
            user_inventory[item.type] = [i 
                                         for i in user_items 
                                         if i.type == item.type]
    return user_inventory

# %%
def print_user_inventory(inventory):
    for itype, ilist in inventory.items():
        try:
            print(f"{itype}\n{'-'*50}")
            for i in ilist:
                print(f"{' ':3}{i.title:50}")
            print("\n")
        except Exception as e:
            print(f"\t\tOperation failed on: {i.title}")
            print(f"\t\tException: {sys.exc_info()[1]}")
            continue

# %%
def get_fs_webmaps(fs, inv):
    fs_webmap_inventory = {}
    fs_inv = []
    try:
        for wm in inv['Web Map']:
            if fs.id in get_layer_item_ids(wm):
                if not wm in fs_inv:
                    fs_inv.append(wm)
        fs_webmap_inventory[fs.title] = fs_inv
        return fs_webmap_inventory
    except KeyError as ke:
        pass

# %%
def get_layer_item_ids(wm):
    wmo = WebMap(wm)
    wm_id_list = []
    for layer in wmo.layers:
        try:
            fsvc = FeatureLayerCollection(layer['url'][:-1], active_gis)
            if not fsvc.properties['serviceItemId'] in wm_id_list:
                wm_id_list.append(fsvc.properties['serviceItemId'])
        except Exception as e:
            pass
    return wm_id_list

# %%
def get_dash_wm(dash):
    return [active_gis.content.get(widget['itemId']) 
            for widget in dash.get_data()['widgets'] 
            if widget['type'] == "mapWidget"]

# %%
source_admin_inventory = get_user_items(source.users.me, source)

# %%
print_user_inventory(source_admin_inventory)
# Out:
# Feature Service
# --------------------------------------------------
#    N2_AllParcels
#    UAV Checklist
#    TBM_Alignment_forTunneling
#    Geotech_TSS
#    TBM_Assembly_Progress
#    NSRP_SC_Alignment
#    Depot_building
#    AsBuilt
#    SC_Landlocked Table
#    SES_Validation_Tool_Betav04
#    Labels
#    Priority
#    Status of Land Acquisition
#    AffectedAreasLandlockedSC
#    NSCR_Ex PROW
#    Utility_Relocation
#    Test_Dataset_Clone_to_Portal
#    N2_ROW
#    Environment_Monitoring_Points_n2
#    SES_Validation_Tool_Betav04
#    SC_PotentialLandlocked_Point
#    Pier_ID_N2
#    GRMmapTrialDirection
#    SES_Validation_Tool_Betav04
#    SC Contactless Attendance
#    Viaduct_N2
#    SC_Free_and_Clear
#    SES Validation Survey
#    Station_N2SC
#    Lot Boundary
#    Tree Cutting and Compensation Dataset
#    N2N01_Landlocked
#    N2_Parcels_forPublic
#    Station_N2
#    MCRP Centerline Chainage
#    SC_Stations
#    Status of LA_N2
#    Structure_SC
#    Parcellary_Structure_SC
#    TBM_Alignment
#    TBM_Assemly_WSL1
#    SC RAP - SCM and Appraisal
#    SC_PotentialLandlocked_Polygon
#    Status of Structure (NLO/LO)_N2
#    Parcellary_Municipaly_and_Barangay_disso
#    PierHead_Column_N2
#    SES Validation for Training Tool
#    Station_mmsp
#    SES Validation Tool for NLO
#    TBM_Spot
#    Dilapidation_Survey
#    SES_Validation_Tool_Betav04_stakeholder
#    PlansandDrawings
#    N2_Centerline
#    SC_Centerline
#    NCR_Railways
#    Station_Box_N2
#    Trees_N2
#    Status for Relocation (ISF)_N2
#    N2N01_LLRoads
#    Utility_Relocation_Dataset
#    Status of Structure_N2
#    Station_Box
#    N2_Free_and_Clear
#    PotentialAccessSC
#    TEST_clone_to_PORTAL
#    SC_Landlocked_WFL1
#    Status of Relocation (Occupancy)_N2
#    Station_N2SC
#    OBS_Bridge
#    Geotech_TSS
#
#
# Scene Service
# --------------------------------------------------
#    OBS_Bridge
#    Station_mmsp
#    Station_N2SC
#    Viaduct_N2
#    TBM_Assemly_WSL1
#    Depot_building
#
#
# Service Definition
# --------------------------------------------------
#    AsBuilt_Compiled_N2_points
#    Station_N2
#    AsBuilt
#    Pier_ID_N2
#    Utility Relocation Arrow
#    N2_UtilityPoint_Existing
#    TBM_Spot
#    Dilapidation_Survey
#    Utility_Relocation
#    Station_N2SC
#    MCRP_UtilityLines_Relocation
#    N2N01_LLRoads
#    TBM_Alignment_forTunneling
#    OBS_Bridge
#    NSCR_Ex PROW
#    SC_Landlocked_WFL1
#    TBM_Alignment
#    Station_mmsp
#    Depot_building
#    TEST_clone_to_PORTAL
#    Test_Dataset_Clone_to_Portal
#    Parcellary_Municipaly_and_Barangay_disso
#    Trees_N2
#    SC_Free_and_Clear
#    NSRP_SC_Alignment
#    Geotech_TSS
#    SC_Stations
#    SC_Centerline
#    AsBuilt_Compiled_N2
#    TBM_Assemly_WSL1
#    MCRP Centerline Chainage
#    N2_Free_and_Clear
#    TBM_Assembly_Progress
#    SC_PotentialLandlocked_Polygon
#    PierHead_Column_N2
#    Status for Relocation_N2
#    NCR_Railways
#    Parcellary_Structure_SC
#    PotentialAccessSC
#    Structure_N2_NLO_LO
#    Station_Box
#    Utility_Relocation_Dataset
#    N2_Parcels_forPublic
#    Parcellary_compiled_N2
#    Viaduct_N2
#    N2N01_Landlocked
#    Labels
#    testPointUtil
#    AffectedAreasLandlockedSC
#    Structure_SC
#    SC_PotentialLandlocked_Point
#    Status of Land Acquisition
#    Tree Cutting and Compensation Dataset
#    Environment_Monitoring_Points_n2
#
#
# Desktop Style
# --------------------------------------------------
#    Utility Pole
#    3D_Electric_Pole
#    Utility Pole
#
#
# Dashboard
# --------------------------------------------------
#    GRM Portal
#    Status of Pre-Construction_N2
#    SC_Landlocked_Dashboard
#    Status of Tree Cutting and Conservation (N2)
#    Status of Relocation_ISF (N2) _rev2
#    Status of Land Acquisition (MMSP)
#    Utility Relocation (N2)
#    Status of Tree Inventoried (N2)
#    Status of Relocation_ISF (N2) _rev1
#    Status of Land Acquisition (MMSP) - compiled
#    00-Pre-Construction Status (N2)
#    Pre-Construction Status (MMSP)
#    00-Status of Land and Structure (MMSP)
#    Status of Land Acquisition (MMSP)  - Priority1
#    NSCR-Ex Project (GRM Website)
#    Sample_DeleteLater
#    Status of Land and Structure Acquisition (N2)-rev1
#    Status of Tree Compensation_N2
#    Status of Land and Structure Acquisition (N2)
#    TBM Assembly
#
#
# Microsoft Word
# --------------------------------------------------
#    UAVFlightReport.docx
#    SES_temp1.docx
#
#
# Web Mapping Application
# --------------------------------------------------
#    GRM Website Map
#    Gallery for Civil Construction
#    Utility Relocation (MMSP)
#    Station Structures (MMSP)
#    Station Structure (N2)
#    Tree Cutting and Compensation (MMSP)
#    Viaduct  sample (N2)
#    Rail Sector Maps
#    Environment Monitoring (N2)
#    Gallery for Utility Relocation
#    TBM Assembly
#    GRM Map
#    Tree Cutting & Compensation (N2)
#    Gallery for Land Acquisition & Tree Cutting
#    Utility Relocation (N2) editor
#    North South Commuter Railway Extension Project
#    Depot Building (MMSP)
#    TBM Tunnel (MMSP)
#    Utility Relocation (N2)
#
#
# Web Scene
# --------------------------------------------------
#    TBM_Assemly
#
#
# Form
# --------------------------------------------------
#    SES Validation Tool for NLO
#    SES_Validation_Tool_Betav04
#    UAV Checklist
#    SC RAP - SCM and Appraisal
#    SES Validation for Training Tool
#    SC Contactless Attendance
#
#
# Web Map
# --------------------------------------------------
#    NSCR-Ex Stations
#    Status of Tree Cutting and Conservation (N2)
#    N2 Parcellary
#    SES Validation Survey Dispatcher Map
#    SES Validation Tool for NLO
#    SC RAP - SCM and Appraisal
#    TEST_clone_to_PORTAL
#    SES Validation Survey
#    Status of Relocation (ISF)_N2
#    Status of Land Acquisition (MMSP)
#    N2_LA_basemap
#    SES Validation for Training Tool
#    CPN01_landlocked
#    00-Land and Structure (MMSP)
#    SC_Landlocked_Street
#    Status of Land Acquisition (MMSP)-Priority1
#    SC Contactless Attendance
#    Status of Tree Compensation_N2
#    Pre-Construction Status (N2)
#    Survey123_BanlicTrial
#    Utility Relocation (N2)
#    TBM_Assembly
#    Status for Relocation (ISF)_N2
#    SC_Landlocked
#    Status of Land and Structure Acquisition (N2)
#    Status of Land and Structure Acquisition (SC)
#    00-Pre-Construction Status (MMSP)
#    UAV Checklist
#
#
# Shapefile
# --------------------------------------------------
#    Lot Affected by N2-SC Ex Project
#    AsBuilt_Compiled_N2
#
#
# Replication Package
# --------------------------------------------------
#    c1a7efa9-6d74-4923-99e3-85cdfe66be0d.crpk
#    8231fb95-017b-43a6-bd10-98b3dbde42ec.crpk
#
#
# Tile Package
# --------------------------------------------------
#    DEM_mmsp
#
#
# Code Attachment
# --------------------------------------------------
#    GRM Map
#    TBM Assembly
#
#
# Hub Initiative
# --------------------------------------------------
#    Railway Project
#
#
# Web Experience
# --------------------------------------------------
#    Untitled experience 1
#
#
# Hub Site Application
# --------------------------------------------------
#    Railway Project
#
#
# Style
# --------------------------------------------------
#    Utility Pole
#
#
# Map Service
# --------------------------------------------------
#    Geotech_TSS
#
#
# Image Service
# --------------------------------------------------
#    DEM_mmsp
#
#
# CSV
# --------------------------------------------------
#    SC_Landlocked Table
#
#
# Image
# --------------------------------------------------
#    SC_image_sample1

# %%
for item_type in list(source_admin_inventory.keys()):
    print(item_type)
# Out:
# Feature Service
# Scene Service
# Service Definition
# Desktop Style
# Dashboard
# Microsoft Word
# Web Mapping Application
# Web Scene
# Form
# Web Map
# Shapefile
# Replication Package
# Tile Package
# Code Attachment
# Hub Initiative
# Web Experience
# Hub Site Application
# Style
# Map Service
# Image Service
# CSV
# Image

# %% [markdown]
# ### Feature Services (Hosted)
#
# Clone hosted feature services. Please note that non-hosted feature services (i.e., registered feature services) cannot be cloned.
# ###### If web maps or operations dashboard is cloned, skip this process

# %%
# Extract only hosted feature layer from Feature Service
hosted_fsvc = [fs 
               for fs in source_admin_inventory["Feature Service"]
               if 'Hosted Service' in fs.typeKeywords]
hosted_fsvc
# Out:
# [<Item title:"TEST_clone_to_PORTAL" type:Feature Layer Collection owner:eijimatsuzaki1>]

# %%
# Search by owner
my_content = source.content.search(query="owner:" + "matsuzakieijinscrex",
                                  item_type = "Feature Layer",
                                  max_items=15)

# %%
search_result = source.content.search(query="title:TEST*")
search_result
# Out:
# [<Item title:"Test_Dataset_Clone_to_Portal" type:Feature Layer Collection owner:matsuzakieijinscrex>, <Item title:"TEST_clone_to_PORTAL" type:Web Map owner:matsuzakieijinscrex>, <Item title:"TEST_clone_to_PORTAL" type:Service Definition owner:matsuzakieijinscrex>, <Item title:"Test_Dataset_Clone_to_Portal" type:Service Definition owner:matsuzakieijinscrex>, <Item title:"testPointUtil" type:Service Definition owner:matsuzakieijinscrex>, <Item title:"TEST_clone_to_PORTAL" type:Feature Layer Collection owner:matsuzakieijinscrex>]

# %%
# Search by title
hosted_fsvc = source.content.search(query="title:Test_Dataset_Clone_to_Portal", item_type="Feature Layer")
hosted_fsvc
# Out:
# [<Item title:"Test_Dataset_Clone_to_Portal" type:Service Definition owner:matsuzakieijinscrex>]

# %%
hosted_fsvc = source.content.search(query="title:Test_Dataset_Clone_to_Portal", item_type="Service Definition")
hosted_fsvc

# %%
# Clone selected hosted feature layer from source to target
for hfs in hosted_fsvc:
    try:
        if hfs.ownerFolder:
            folder = next((f['title'] 
                          for f in source.users.me.folders 
                          if f['id'] == hfs.ownerFolder))
            if not folder in [fld['title']
                              for fld in target.users.me.folders]:
                target.content.create_folder(folder=folder)
            print(f"Cloning {hfs.title}...")
            clone_fs = target.content.clone_items([hfs], folder=folder)
            print(f"...completed")
        else:
            print(f"Cloning {hfs.title}...")
            cloned_fs = target.content.clone_items([hfs])
            if not cloned_fs:
                print(f"{hfs.title} not cloned")
            else:
                print(f"...completed")       
    except Exception as e:
        print(f"...Failed to Clone {hfs.title}...")
        print(f"\tException Type: {sys.exc_info()[0]}")
        print(f"\tException Value: {sys.exc_info()[1]}")
        print(f"\tException Traceback line: {sys.exc_info()[2].tb_lineno}")
        print(f"\tException Traceback instruction: {sys.exc_info()[2].tb_lasti}")
        continue
# Out:
# Cloning Test_Dataset_Clone_to_Portal...
# ...completed

# %%
# Query the target to inspect the results of cloning the feature services
target_admin_inventory = get_user_items(target.users.me, target)

# %%
print_user_inventory(target_admin_inventory)
# Out:
# Data Store
# --------------------------------------------------
#    Basedata_nscrex_n2
#    DuringConstructionNSCREXN2
#    DOTr_User
#    TS_StationBox
#    Basedata_nstren
#    Basedata_mmsp
#    Pre_Construction_nscrex_sc
#    Basedata_nscrex_sc
#
#
# Image Service
# --------------------------------------------------
#    DEM_PO_mmsp
#    DEM_mmsp
#
#
# Web Scene
# --------------------------------------------------
#    My Scene
#    Default Web Scene
#    TBM Assembly
#
#
# Service Definition
# --------------------------------------------------
#    DEM
#    Civil_EIJI_PILECAP_surface_testDelete
#    N2_Trees
#    Land_Acquisition_mmsp_WFL1
#    Tree Cutting and Compensation_WFL1
#    Alignment_N2
#    Dilapidation_Survey
#    OBS_Bridge
#    TBM_Spot
#    TBM_Alignment
#    TBM Assembly_WSL1
#    TBM_Alignment_for_Assembly
#    Stations_and_Alignment
#    Parcellary_Dissolved_Municipality_and_Barangay
#    Test_Dataset_Clone_to_Portal
#
#
# Geometry Service
# --------------------------------------------------
#    Geometry
#
#
# Geoprocessing Service
# --------------------------------------------------
#    OfflinePackaging
#    GeocodingTools
#    RasterUtilities
#    PrintingTools
#
#
# Map Service
# --------------------------------------------------
#    Stations
#    EVS Boundary
#    testSlider
#    Stations1
#    NSTren_Alignment
#    PO Section
#    SampleWorldCities
#    EVS_Drawings
#    MMSP_Alignment
#    Demolition_Plan_Test
#    Geotech_TSS
#    Station_Structures_mmsp
#    Station_Structure_merged
#    AirPhotoPO12
#    Utility Relocation N2
#    Utility Relocation mmsp
#    TBM Segmented Line
#    Viaduct
#    Pier_N2
#    Alignment_Datasets
#    Parcellary_Structure_Datasets
#    Tree_Inventory_Datasetes
#    PRI_building
#    Tree_Cutting_Compensation_mmsp
#    DEM
#    Station
#    Excavation_Spot
#    TBM_Shaft_CC
#    PierHead_Column_N2
#    Structure _NLO_LO
#    Status_of_Relocation_ISF_N2
#    Cut_and_Cover
#    TBM_Shaft_CutCover_Progress
#
#
# Project Template
# --------------------------------------------------
#    Environmental_Team_v2
#
#
# WMS
# --------------------------------------------------
#    SampleWorldCities
#
#
# Image
# --------------------------------------------------
#    MMSP Logo
#    OtC_status_hatched_symbol_logo
#    TBM_Machine_Logo
#    GCR LOGO
#    MMSP_DOTr_logo
#    DOTr
#    Combined_Logo
#    Shared Theme Logo - MMSP_DOTr_logo
#
#
# Task File
# --------------------------------------------------
#    Update_LAR_Feature_Layer
#
#
# Dashboard
# --------------------------------------------------
#    Rail Sector Maps
#    Status of Tree Compensation (N2)
#    Status of Tree Cutting and Conservation (N2)
#    Tree Inventory (N2)
#    TBM Assembly (MMSP)
#    Land Acquisition (MMSP)
#    Sample_DeleteLater
#    Land Acquisition (MMSP)
#    Land Acquisition-priority1 (MMSP)
#    Status of Land and Structure Acquisition (N2)
#    Construction Boundary(copy)_DeleteLater
#
#
# Web Mapping Application
# --------------------------------------------------
#    ArcGIS Journal for MMSP (SAMPLE)
#    Survey 123 Website
#    Gallery (TEST)
#    Viaduct (N2)
#    Land Acquisition (N2)
#    Rail Sector Maps
#    Station Structures (MMSP)
#    Station Structures (N2)
#    Depot Buildings (MMSP)
#    TBM Tunnel (MMSP)
#    TBM Assembly
#    Gallery for Civil Construction
#    Utility Relocation (MMSP)
#    TBM Shaft and Cut/Cover (MMSP)
#    Tree Cutting & Compensation (MMSP)
#    Gallery for Land Acquisition
#    Gallery for Utility Relocation
#    Utility Relocation (N2)
#    Tree Cutting & Compensation (N2)
#
#
# Scene Service
# --------------------------------------------------
#    testSlider
#    Station_Structure_merged
#    Test_SLPK_BIM
#    OBS_Bridge
#    Station_Structures_mmsp
#    TBM Assembly_WSL1
#    Stations1
#    Viaduct
#    PRI_building
#    TBM_Shaft_CC
#    Cut_and_Cover
#    Station
#
#
# Symbol Set
# --------------------------------------------------
#    OtC Hatched Symbols
#
#
# Feature Service
# --------------------------------------------------
#    Find_Locations_in_Process
#    Demolition_Plan_Test
#    NSTren_Alignment
#    testSlider
#    PO Section
#    EVS_Drawings
#    Tree Cutting and Compensation_WFL1
#    Utility Relocation mmsp
#    Stations_and_Alignment
#    Station_Structure_merged
#    Geotech_TSS
#    Dilapidation_Survey
#    OBS_Bridge
#    TBM Segmented Line
#    TBM_Spot
#    Station_Structures_mmsp
#    TBM Assembly_WSL1
#    Stations
#    TBM_Alignment_for_Assembly
#    Viaduct
#    PRI_building
#    MMSP_Alignment
#    EVS Boundary
#    Parcellary_Dissolved_Municipality_and_Barangay
#    PierHead_Column_N2
#    Land_Acquisition_mmsp_WFL1
#    Structure _NLO_LO
#    TBM_Shaft_CutCover_Progress
#    Cut_and_Cover
#    TBM_Alignment
#    TBM_Shaft_CC
#    Status_of_Relocation_ISF_N2
#    Pier_N2
#    Utility Relocation N2
#    Station
#    Construction Boundary (copy)
#    Tree_Cutting_Compensation_mmsp
#    Excavation_Spot
#    Alignment_Datasets
#    Tree_Inventory_Datasetes
#    Parcellary_Structure_Datasets
#    Test_Dataset_Clone_to_Portal
#
#
# Map Package
# --------------------------------------------------
#    Practice Map Package
#
#
# Site Application
# --------------------------------------------------
#    Platform for Railway Projects (SAMPLE) - 1
#    GIS Platform for Railway Projects
#
#
# Code Attachment
# --------------------------------------------------
#    TBM Assembly
#
#
# Style
# --------------------------------------------------
#    Utility Pole
#
#
# Scene Package
# --------------------------------------------------
#    Test_SLPK_BIM
#
#
# Web Map
# --------------------------------------------------
#    Sample_DeleteLater
#    BingMaps
#    World Street Map Night No Buildings
#    Tree Cutting and Conservation
#    TBM Assembly
#    Land_Acquisition (MMSP)
#    Construction Boundary(copy)_DeleteLater
#    Rail Sector Maps
#    Tree Compensation
#    Land_Acquisition-priority1 (MMSP)
#    Land_Acquisition_N2

# %%
# Check feature services ID cloned between source and target
target_to_source = {}
for targ_fsvc_item in target_admin_inventory['Feature Service']:
    for keyword in targ_fsvc_item.typeKeywords:
        if 'source' in keyword:
            source_id = keyword.split('-')[1]
            try:
                flyr = source.content.get(source_id)
                target_to_source[targ_fsvc_item.title] = (keyword,
                                                          flyr.title,
                                                          flyr.id)
            except Exception as e:
                pass
for trg_item, src_item in target_to_source.items():
    print(f"Target Item: {trg_item:45}{src_item[0]}\n{' '*2}"
          f"Source Item: {src_item[1]:45}{src_item[2]}")
    print("\n")
# Out:
# Target Item: Test_Dataset_Clone_to_Portal                 source-99341ac1982b48f697af94b13a774f69
#   Source Item: Test_Dataset_Clone_to_Portal                 99341ac1982b48f697af94b13a774f69

# %%
# Examine the target feature services to see that we also created the folder structure
target_hosted_fsvc = [fs 
               for fs in target_admin_inventory["Feature Service"]
               if 'Hosted Service' in fs.typeKeywords]

# %%
target_hosted_fsvc
# Out:
# [<Item title:"Find_Locations_in_Process" type:Feature Layer Collection owner:matsuzakieiji>, <Item title:"Tree Cutting and Compensation_WFL1" type:Feature Layer Collection owner:matsuzakieiji>, <Item title:"Stations_and_Alignment" type:Feature Layer Collection owner:matsuzakieiji>, <Item title:"Dilapidation_Survey" type:Feature Layer Collection owner:matsuzakieiji>, <Item title:"OBS_Bridge" type:Feature Layer Collection owner:matsuzakieiji>, <Item title:"TBM_Spot" type:Feature Layer Collection owner:matsuzakieiji>, <Item title:"TBM Assembly_WSL1" type:Feature Layer Collection owner:matsuzakieiji>, <Item title:"TBM_Alignment_for_Assembly" type:Feature Layer Collection owner:matsuzakieiji>, <Item title:"Parcellary_Dissolved_Municipality_and_Barangay" type:Feature Layer Collection owner:matsuzakieiji>, <Item title:"Land_Acquisition_mmsp_WFL1" type:Feature Layer Collection owner:matsuzakieiji>, <Item title:"TBM_Alignment" type:Feature Layer Collection owner:matsuzakieiji>, <Item title:"Test_Dataset_Clone_to_Portal" type:Feature Layer Collection owner:matsuzakieiji>]

# %%
active_gis = target

# %%
print(f"{'Feature Layer':<33}{'Folder ID':<35}{'Folder Name':15}{'Item ID'}\n"
      f"{'-'*28:<30}{'-'*33:<35}{'-'*13:<15}{'-'*37}")
for hosted_fs in target_hosted_fsvc:
    try:
        fs_wm_maps = get_fs_webmaps(hosted_fs, target_admin_inventory)[hosted_fs.title]
    except TypeError as te:
        pass
        continue
    finally:
        if not hosted_fs.ownerFolder:
            print(f"{hosted_fs.title[:30]:33}{' ':35}{'Root Folder':15}{hosted_fs.id}")
            if fs_wm_maps:
                for wm in fs_wm_maps:
                    print(f"{' '*2}...consumed in {wm.title} web map")
            else:
                pass
        else:
            print(f"{hosted_fs.title[:30]:33}{hosted_fs.ownerFolder:35}"
                  f"""{next(f['title'] for f in target.users.me.folders 
                   if f['id'] == hosted_fs.ownerFolder):15}"""
                  f"{hosted_fs.id}")
            if fs_wm_maps:
                for wm in fs_wm_maps:
                    print(f"{' '*2}...consumed in {wm.title} web map")
            else:
                pass
        print("\n")
# Out:
# Feature Layer                    Folder ID                          Folder Name    Item ID
# ----------------------------  ---------------------------------  -------------  -------------------------------------
# Find_Locations_in_Process        b72d1976bb6a49af95083a3c1d9c6a45   MMSP_duringC   c3df35e180dd4cb3a8883c992cd170e6
#
#
# Tree Cutting and Compensation_   c9fedb0b17c946689bf13b78b103f12a   NSCR-Ex_preC   7402e136afb942bd8cb3540b3d11ea78
#   ...consumed in Tree Cutting and Conservation web map
#   ...consumed in Tree Compensation web map
#
#
# Stations_and_Alignment                                              Root Folder    9d9645abbda248d095d89d7637446f52
#
#
# Dilapidation_Survey              b72d1976bb6a49af95083a3c1d9c6a45   MMSP_duringC   4a1a7a7416f74cccaaab22a06b04e47d
#
#
# OBS_Bridge                       b72d1976bb6a49af95083a3c1d9c6a45   MMSP_duringC   b716fbf174bf4519b92272e4ee6014a0
#
#
# TBM_Spot                         b72d1976bb6a49af95083a3c1d9c6a45   MMSP_duringC   bf98937409884516b244367421c83461
#
#
# TBM Assembly_WSL1                01f10f3e5c094227846c7cc6fff8af27   MMSP_preC      00db5f28390c4deda3b4aca478aa6887
#
#
# TBM_Alignment_for_Assembly       01f10f3e5c094227846c7cc6fff8af27   MMSP_preC      7a5b88d46d1d4bc08e2a9d3567750875
#   ...consumed in TBM Assembly web map
#
#
# Parcellary_Dissolved_Municipal   c9fedb0b17c946689bf13b78b103f12a   NSCR-Ex_preC   87e3af8726fe4f9a93018ec263e797da
#   ...consumed in Land_Acquisition_N2 web map
#
#
# Land_Acquisition_mmsp_WFL1       01f10f3e5c094227846c7cc6fff8af27   MMSP_preC      86159bef446a4de991365c0b89c2bc4c
#   ...consumed in TBM Assembly web map
#   ...consumed in Land_Acquisition (MMSP) web map
#   ...consumed in Construction Boundary(copy)_DeleteLater web map
#   ...consumed in Land_Acquisition-priority1 (MMSP) web map
#
#
# TBM_Alignment                    b72d1976bb6a49af95083a3c1d9c6a45   MMSP_duringC   1f9ddc8d8fcf4618acafbf8c1647d10c
#
#
# Test_Dataset_Clone_to_Portal     15a1ff7dc42a4891bcd6c517b7bde210   Test           67671a3368c144bb80331b8421a7644b

# %% [markdown]
# ### Web Maps
#
# Clone Web Maps and hosted feature services consumed in the web maps.
# NOTE: non-hosted feature services (e.g., registered feature services) are not cloned but only reference.
#       This means that you need to sign in the Portal for ArcGIS when web maps makes a reference to the
#       the registered feature services.

# %%
# Look at the Web Maps in our source organization
for wm in source_admin_inventory['Web Map']:
    wm_obj = WebMap(wm)
    print(wm_obj.item.title)
# Out:
# NSCR-Ex Stations
# Status of Tree Cutting and Conservation (N2)
# N2 Parcellary
# SES Validation Survey Dispatcher Map
# SES Validation Tool for NLO
# SC RAP - SCM and Appraisal
# TEST_clone_to_PORTAL
# SES Validation Survey
# Status of Relocation (ISF)_N2
# Status of Land Acquisition (MMSP)
# N2_LA_basemap
# SES Validation for Training Tool
# CPN01_landlocked
# 00-Land and Structure (MMSP)
# SC_Landlocked_Street
# Status of Land Acquisition (MMSP)-Priority1
# SC Contactless Attendance
# Status of Tree Compensation_N2
# Pre-Construction Status (N2)
# Survey123_BanlicTrial
# Utility Relocation (N2)
# TBM_Assembly
# Status for Relocation (ISF)_N2
# SC_Landlocked
# Status of Land and Structure Acquisition (N2)
# Status of Land and Structure Acquisition (SC)
# 00-Pre-Construction Status (MMSP)
# UAV Checklist

# %%
# Inpsect what layers are in each Web Map

# %%
def is_hosted(item):
    return [keyword for keyword in item.typeKeywords if "Hosted" in keyword]

# %%
def print_webmap_inventory(wm):
    wm_obj = WebMap(wm)
    print(f"{wm_obj.item.title}\n{'-'*100}")
    for wm_layer in wm_obj.layers:
        try:
            if is_hosted(Item(active_gis, wm_layer['itemId'])):
                print(f"{' '*2}{wm_layer['title']:40}HOSTED{' ':5}"
                      f"{wm_layer['layerType']:20}{dict(wm_layer)['itemId']}")
            else:
                print(f"{' '*2}{wm_layer['title']:40}other{' ':6}"
                      f"{wm_layer['layerType']:20}{wm_layer.id}") 
        except:
            print(f"{' '*2}{wm_layer['title']:40}other{' ':6}"
                  f"{wm_layer['layerType']:20}{wm_layer.id}")
    print("\n")

# %%
# Remember to set the active_gis variable when using the helper functions
active_gis = source

# %%
# This helper function may also freeze.
for wm in source_admin_inventory['Web Map']:
    print_webmap_inventory(wm)
# Out:
# NSCR-Ex Stations
# ----------------------------------------------------------------------------------------------------
#   Labels                                  HOSTED     ArcGISFeatureLayer  4cf42c35bf024eda9e926b273fdbaa05
#   Solis - Calamba Stations                HOSTED     ArcGISFeatureLayer  fc0c7e4745a247a8b9893f5311754181
#   Solis - Calamba Alignment               HOSTED     ArcGISFeatureLayer  d7f2148cf56f45428db7147f116fce9a
#   Malolos - Clark Stations                HOSTED     ArcGISFeatureLayer  36f7d5fd1a5c444fbfcb2bf2897c3993
#   Malolos - Clark Alignment               HOSTED     ArcGISFeatureLayer  d0f7efbb44af4285b52df5a34695c669
#   NCR_Railways                            HOSTED     ArcGISFeatureLayer  a22c1df2832b4088a00f3d7f566ede88
#
#
# Status of Tree Cutting and Conservation (N2)
# ----------------------------------------------------------------------------------------------------
#   PROW                                    HOSTED     ArcGISFeatureLayer  878c49e145b34f269947f8584cd3512c
#   Conservation                            HOSTED     ArcGISFeatureLayer  515c18f3b5204f9b9d7d047e30a94b2f
#   Status of Tree Cutting                  HOSTED     ArcGISFeatureLayer  515c18f3b5204f9b9d7d047e30a94b2f
#   Station                                 HOSTED     ArcGISFeatureLayer  16ed67786ee846018169fa00da3bc586
#
#
# N2 Parcellary
# ----------------------------------------------------------------------------------------------------
#   ChainagePoints100                       other      ArcGISFeatureLayer  ChainagePoints100_shapefile_8907
#   N2_Centerline                           HOSTED     ArcGISFeatureLayer  d0f7efbb44af4285b52df5a34695c669
#   N2_ROW                                  HOSTED     ArcGISFeatureLayer  0e77ef47f9e240cabe4baf5673e75986
#   N2_AllParcels                           HOSTED     ArcGISFeatureLayer  76203e105a3a4ec6a31fa119db680c36
#
#
# SES Validation Survey Dispatcher Map
# ----------------------------------------------------------------------------------------------------
#   Workers                                 HOSTED     ArcGISFeatureLayer  483b6be6b5cb4f349984b3ec2f5cbb98
#   Assignments                             HOSTED     ArcGISFeatureLayer  483b6be6b5cb4f349984b3ec2f5cbb98
#
#
# SES Validation Tool for NLO
# ----------------------------------------------------------------------------------------------------
#   SES Validation Tool for NLO             HOSTED     ArcGISFeatureLayer  ff6171de487d4e5a80745f5841a116f7
#
#
# SC RAP - SCM and Appraisal
# ----------------------------------------------------------------------------------------------------
#   SC RAP - SCM and Appraisal              HOSTED     ArcGISFeatureLayer  3ca299657dfa4278aa399822079669e8
#
#
# TEST_clone_to_PORTAL
# ----------------------------------------------------------------------------------------------------
#   TEST_clone_to_PORTAL                    HOSTED     ArcGISFeatureLayer  8bff96a629b14f3ca94060613262853c
#
#
# SES Validation Survey
# ----------------------------------------------------------------------------------------------------
#   Workers                                 HOSTED     ArcGISFeatureLayer  483b6be6b5cb4f349984b3ec2f5cbb98
#   Assignments                             HOSTED     ArcGISFeatureLayer  483b6be6b5cb4f349984b3ec2f5cbb98
#
#
# Status of Relocation (ISF)_N2
# ----------------------------------------------------------------------------------------------------
#   Pier Head/Column                        HOSTED     ArcGISFeatureLayer  d6a26319b66141e5861d4662c009b961
#   Pier No                                 HOSTED     ArcGISFeatureLayer  133a8266943247ffaaf44b41f94d08f4
#   Chainage                                HOSTED     ArcGISFeatureLayer  7e1812db542a4261b73787dfe5a5d438
#   Alignment CenterLine                    HOSTED     ArcGISFeatureLayer  7e1812db542a4261b73787dfe5a5d438
#   Free and Clear                          HOSTED     ArcGISFeatureLayer  e5f46f9a7a3a44879ad0420ccff3f33e
#   Priority Lots                           HOSTED     ArcGISFeatureLayer  3e31d434ec9a4e7b978dec0d99059ee5
#   Status for Relocation (ISF)_N2          HOSTED     ArcGISFeatureLayer  414bf052e9344cd58125adbe10d2520d
#   Status for Relocation (Occupancy)       HOSTED     ArcGISFeatureLayer  c12eddbc2bb346208e4af16048a43947
#   Structure Boundary                      HOSTED     ArcGISFeatureLayer  442de7a0e25d4eaa8b6b3fe2e3b68262
#   Station_N2                              HOSTED     ArcGISFeatureLayer  36f7d5fd1a5c444fbfcb2bf2897c3993
#   NSCR_Ex PROW                            HOSTED     ArcGISFeatureLayer  878c49e145b34f269947f8584cd3512c
#   Structure (NLO/LO)                      HOSTED     ArcGISFeatureLayer  9c00382e131847288ee9c02f09badcf1
#   Structure (Mode of Acquisition)         other      ArcGISFeatureLayer  176549daf34-layer-2_3274
#   Status of Structure                     HOSTED     ArcGISFeatureLayer  442de7a0e25d4eaa8b6b3fe2e3b68262
#   Status of Land Acquisition              HOSTED     ArcGISFeatureLayer  3e31d434ec9a4e7b978dec0d99059ee5
#   Land (Mode of Acquisition)              other      ArcGISFeatureLayer  Parcellary_compiled_N2_6966_9609
#   Lot Boundary                            HOSTED     ArcGISFeatureLayer  3e31d434ec9a4e7b978dec0d99059ee5
#   Station_Box                             HOSTED     ArcGISFeatureLayer  f9f53223e41e4006b76484c04a2b9916
#   Municipality (one boundary)             HOSTED     ArcGISFeatureLayer  fcb7c73a624e40d9ac12cea319427ff8
#   Barangay (one boundary)                 HOSTED     ArcGISFeatureLayer  fcb7c73a624e40d9ac12cea319427ff8
#
#
# Status of Land Acquisition (MMSP)
# ----------------------------------------------------------------------------------------------------
#   Station                                 HOSTED     ArcGISFeatureLayer  4f155bc22b4d461fa3c09ea256b1e3a4
#   Drainage                                HOSTED     ArcGISFeatureLayer  4f155bc22b4d461fa3c09ea256b1e3a4
#   PO Section                              HOSTED     ArcGISFeatureLayer  4f155bc22b4d461fa3c09ea256b1e3a4
#   EVS Drawings                            HOSTED     ArcGISFeatureLayer  4f155bc22b4d461fa3c09ea256b1e3a4
#   Construction Boundary                   HOSTED     ArcGISFeatureLayer  4f155bc22b4d461fa3c09ea256b1e3a4
#   Creek Diversion                         HOSTED     ArcGISFeatureLayer  4f155bc22b4d461fa3c09ea256b1e3a4
#   Creek                                   HOSTED     ArcGISFeatureLayer  4f155bc22b4d461fa3c09ea256b1e3a4
#   Depot Building                          HOSTED     ArcGISFeatureLayer  4f155bc22b4d461fa3c09ea256b1e3a4
#   Priority                                other      ArcGISFeatureLayer  1781ea259d9-layer-14
#   BSS Building                            HOSTED     ArcGISFeatureLayer  4f155bc22b4d461fa3c09ea256b1e3a4
#   Status                                  HOSTED     ArcGISFeatureLayer  4f155bc22b4d461fa3c09ea256b1e3a4
#   Lot Boundary                            other      ArcGISFeatureLayer  1781ea24b69-layer-13
#   Property Boundary (Senate)              HOSTED     ArcGISFeatureLayer  4f155bc22b4d461fa3c09ea256b1e3a4
#
#
# N2_LA_basemap
# ----------------------------------------------------------------------------------------------------
#   Graphics Layer                          other      ArcGISFeatureLayer  db53c592164f494f944c979e06722cb1
#   Chainage                                HOSTED     ArcGISFeatureLayer  7e1812db542a4261b73787dfe5a5d438
#   Alignment CenterLine                    HOSTED     ArcGISFeatureLayer  7e1812db542a4261b73787dfe5a5d438
#   Free and Clear                          HOSTED     ArcGISFeatureLayer  e5f46f9a7a3a44879ad0420ccff3f33e
#   Priority Lots                           HOSTED     ArcGISFeatureLayer  3e31d434ec9a4e7b978dec0d99059ee5
#   Structure Boundary                      HOSTED     ArcGISFeatureLayer  442de7a0e25d4eaa8b6b3fe2e3b68262
#   Station_N2                              HOSTED     ArcGISFeatureLayer  36f7d5fd1a5c444fbfcb2bf2897c3993
#   NSCR_Ex PROW                            HOSTED     ArcGISFeatureLayer  878c49e145b34f269947f8584cd3512c
#   Status for Relocation                   HOSTED     ArcGISFeatureLayer  c12eddbc2bb346208e4af16048a43947
#   Status of Structure                     HOSTED     ArcGISFeatureLayer  442de7a0e25d4eaa8b6b3fe2e3b68262
#   Status of Land Acquisition              HOSTED     ArcGISFeatureLayer  3e31d434ec9a4e7b978dec0d99059ee5
#   Lot Boundary                            HOSTED     ArcGISFeatureLayer  3e31d434ec9a4e7b978dec0d99059ee5
#   Station_Box_N2                          HOSTED     ArcGISFeatureLayer  9ccf8eadda704960b3559c697ce1f0c9
#
#
# SES Validation for Training Tool
# ----------------------------------------------------------------------------------------------------
#   SES Validation for Training Tool        HOSTED     ArcGISFeatureLayer  94af0fd8a8ff46b5bfb60b4924efd8f5
#
#
# CPN01_landlocked
# ----------------------------------------------------------------------------------------------------
#   Chainage                                HOSTED     ArcGISFeatureLayer  7e1812db542a4261b73787dfe5a5d438
#   Roads (Possible Loss of Access)         HOSTED     ArcGISFeatureLayer  ca3df3508a2f4c89a79a158a8397ba9b
#   Possible Landlocked                     HOSTED     ArcGISFeatureLayer  055e66e9d65442fb959aa08874200d5a
#   Project ROW                             HOSTED     ArcGISFeatureLayer  878c49e145b34f269947f8584cd3512c
#   Parcellary                              HOSTED     ArcGISFeatureLayer  3aeb3d980fdf4e32893ee97c4ebe45b2
#
#
# 00-Land and Structure (MMSP)
# ----------------------------------------------------------------------------------------------------
#   Station                                 HOSTED     ArcGISFeatureLayer  4f155bc22b4d461fa3c09ea256b1e3a4
#   Drainage                                HOSTED     ArcGISFeatureLayer  4f155bc22b4d461fa3c09ea256b1e3a4
#   PO Section                              HOSTED     ArcGISFeatureLayer  4f155bc22b4d461fa3c09ea256b1e3a4
#   EVS Drawings                            HOSTED     ArcGISFeatureLayer  4f155bc22b4d461fa3c09ea256b1e3a4
#   Construction Boundary                   HOSTED     ArcGISFeatureLayer  4f155bc22b4d461fa3c09ea256b1e3a4
#   Creek Diversion                         HOSTED     ArcGISFeatureLayer  4f155bc22b4d461fa3c09ea256b1e3a4
#   Creek                                   HOSTED     ArcGISFeatureLayer  4f155bc22b4d461fa3c09ea256b1e3a4
#   Depot Building                          HOSTED     ArcGISFeatureLayer  4f155bc22b4d461fa3c09ea256b1e3a4
#   Priority                                other      ArcGISFeatureLayer  1781ea259d9-layer-14
#   BSS Building                            HOSTED     ArcGISFeatureLayer  4f155bc22b4d461fa3c09ea256b1e3a4
#   Structure (Mode of Acquisition)         other      ArcGISFeatureLayer  1781e8c19e4-layer-3_3328_6030
#   Status of Land Acquisition              HOSTED     ArcGISFeatureLayer  4f155bc22b4d461fa3c09ea256b1e3a4
#   Land (Mode of Acquisition)              other      ArcGISFeatureLayer  1781e8c19e4-layer-3_3328
#   Lot Boundary                            other      ArcGISFeatureLayer  1781ea24b69-layer-13
#   Property Boundary (Senate)              HOSTED     ArcGISFeatureLayer  4f155bc22b4d461fa3c09ea256b1e3a4
#
#
# SC_Landlocked_Street
# ----------------------------------------------------------------------------------------------------
#   AffectedAreasLandlockedSC               HOSTED     ArcGISFeatureLayer  8b586731718d4415bfcc725e25644af9
#   PotentialAccessSC                       HOSTED     ArcGISFeatureLayer  9fefc1af5d7a4c289734643b4cc00812
#   SC_PotentialLandlocked_Point            HOSTED     ArcGISFeatureLayer  581fbb2ee7b7438abbfbf6016316148c
#   SC_PotentialLandlocked_Polygon          HOSTED     ArcGISFeatureLayer  39b04a5f445c4768807d676f8a6fdf0b
#   SC_Centerline                           HOSTED     ArcGISFeatureLayer  6b070349c5f74a119cf33a8a925dee95
#   SC_Chainage                             HOSTED     ArcGISFeatureLayer  6b070349c5f74a119cf33a8a925dee95
#   SC_Parcellary                           HOSTED     ArcGISFeatureLayer  6b070349c5f74a119cf33a8a925dee95
#   SC_PROW                                 HOSTED     ArcGISFeatureLayer  6b070349c5f74a119cf33a8a925dee95
#   Structure_SC                            HOSTED     ArcGISFeatureLayer  cc7d0ef7e1144144b71d06dbf2c1ae9b
#
#
# Status of Land Acquisition (MMSP)-Priority1
# ----------------------------------------------------------------------------------------------------
#   Station                                 HOSTED     ArcGISFeatureLayer  4f155bc22b4d461fa3c09ea256b1e3a4
#   Drainage                                HOSTED     ArcGISFeatureLayer  4f155bc22b4d461fa3c09ea256b1e3a4
#   PO Section                              HOSTED     ArcGISFeatureLayer  4f155bc22b4d461fa3c09ea256b1e3a4
#   EVS Drawings                            HOSTED     ArcGISFeatureLayer  4f155bc22b4d461fa3c09ea256b1e3a4
#   Construction Boundary                   HOSTED     ArcGISFeatureLayer  4f155bc22b4d461fa3c09ea256b1e3a4
#   Creek Diversion                         HOSTED     ArcGISFeatureLayer  4f155bc22b4d461fa3c09ea256b1e3a4
#   Creek                                   HOSTED     ArcGISFeatureLayer  4f155bc22b4d461fa3c09ea256b1e3a4
#   Depot Building                          HOSTED     ArcGISFeatureLayer  4f155bc22b4d461fa3c09ea256b1e3a4
#   Priority                                other      ArcGISFeatureLayer  1781ea259d9-layer-14
#   BSS Building                            HOSTED     ArcGISFeatureLayer  4f155bc22b4d461fa3c09ea256b1e3a4
#   Status                                  HOSTED     ArcGISFeatureLayer  4f155bc22b4d461fa3c09ea256b1e3a4
#   Lot Boundary                            other      ArcGISFeatureLayer  1781ea24b69-layer-13
#   Property Boundary (Senate)              HOSTED     ArcGISFeatureLayer  4f155bc22b4d461fa3c09ea256b1e3a4
#
#
# SC Contactless Attendance
# ----------------------------------------------------------------------------------------------------
#   SC Contactless Attendance               HOSTED     ArcGISFeatureLayer  3646d834e6ba4b19b0d7193e9ca97013
#
#
# Status of Tree Compensation_N2
# ----------------------------------------------------------------------------------------------------
#   PROW                                    HOSTED     ArcGISFeatureLayer  878c49e145b34f269947f8584cd3512c
#   Tree Compensation                       HOSTED     ArcGISFeatureLayer  515c18f3b5204f9b9d7d047e30a94b2f
#   Station                                 HOSTED     ArcGISFeatureLayer  16ed67786ee846018169fa00da3bc586
#
#
# Pre-Construction Status (N2)
# ----------------------------------------------------------------------------------------------------
#   Utility Point (Relocated)               other      ArcGISFeatureLayer  Utility_Relocation_20210407_7879_2397
#   Utility Point (Demolished)              HOSTED     ArcGISFeatureLayer  4c889516500442dfb6692315ea474ded
#   Utility Line (Relocated)                HOSTED     ArcGISFeatureLayer  4c889516500442dfb6692315ea474ded
#   Utility Line (Demolished)               other      ArcGISFeatureLayer  Utility_Relocation_20210407_9371_7873
#   Trees (Cut/Earthballed)                 HOSTED     ArcGISFeatureLayer  515c18f3b5204f9b9d7d047e30a94b2f
#   Trees (Paid)                            other      ArcGISFeatureLayer  Trees_N2_5476_7864
#   Relocation (ISF) Relocated              other      ArcGISFeatureLayer  Status_for_Relocation_N2_4244_6253
#   Relocation (ISF) Paid                   HOSTED     ArcGISFeatureLayer  414bf052e9344cd58125adbe10d2520d
#   Structure (HandOver)                    other      ArcGISFeatureLayer  176549daf34-layer-2_8969
#   Structure (Paid)                        HOSTED     ArcGISFeatureLayer  442de7a0e25d4eaa8b6b3fe2e3b68262
#   LA (HandOver)                           other      ArcGISFeatureLayer  Parcellary_compiled_N2_6966_3238
#   LA (Paid)                               HOSTED     ArcGISFeatureLayer  3e31d434ec9a4e7b978dec0d99059ee5
#   Pier Head/Column                        HOSTED     ArcGISFeatureLayer  d6a26319b66141e5861d4662c009b961
#   Station_Box                             HOSTED     ArcGISFeatureLayer  f9f53223e41e4006b76484c04a2b9916
#   Pier No                                 HOSTED     ArcGISFeatureLayer  133a8266943247ffaaf44b41f94d08f4
#   Chainage                                HOSTED     ArcGISFeatureLayer  7e1812db542a4261b73787dfe5a5d438
#   Alignment CenterLine                    HOSTED     ArcGISFeatureLayer  7e1812db542a4261b73787dfe5a5d438
#   Free and Clear                          HOSTED     ArcGISFeatureLayer  e5f46f9a7a3a44879ad0420ccff3f33e
#   Priority Lots                           HOSTED     ArcGISFeatureLayer  3e31d434ec9a4e7b978dec0d99059ee5
#   Structure Boundary                      HOSTED     ArcGISFeatureLayer  442de7a0e25d4eaa8b6b3fe2e3b68262
#   Station_N2                              HOSTED     ArcGISFeatureLayer  36f7d5fd1a5c444fbfcb2bf2897c3993
#   NSCR_Ex PROW                            HOSTED     ArcGISFeatureLayer  878c49e145b34f269947f8584cd3512c
#   Structure_N2_NLO_LO                     HOSTED     ArcGISFeatureLayer  9c00382e131847288ee9c02f09badcf1
#   Status for Relocation (Occupancy)       HOSTED     ArcGISFeatureLayer  c12eddbc2bb346208e4af16048a43947
#   Lot Boundary                            HOSTED     ArcGISFeatureLayer  3e31d434ec9a4e7b978dec0d99059ee5
#   Municipality (one boundary)             HOSTED     ArcGISFeatureLayer  fcb7c73a624e40d9ac12cea319427ff8
#   Barangay (one boundary)                 HOSTED     ArcGISFeatureLayer  fcb7c73a624e40d9ac12cea319427ff8
#
#
# Survey123_BanlicTrial
# ----------------------------------------------------------------------------------------------------
#   service_c8be2806ec8c4fc689ef54dacc13e6a5 - surveyother      ArcGISFeatureLayer  service_c8be2806ec8c4fc689ef54dacc13e6a5_7643
#
#
# Utility Relocation (N2)
# ----------------------------------------------------------------------------------------------------
#   UtilityLine Relocation Arrow            other      ArcGISFeatureLayer  MCRP_UtilityLines_Relocation_8210
#   UtilityLine Proposed Relocation         other      ArcGISFeatureLayer  MCRP_UtilityLines_Relocation_3941
#   UtilityLine Existing                    other      ArcGISFeatureLayer  MCRP_UtilityLines_Relocation_8827
#   Utility Relocation Arrow                other      ArcGISFeatureLayer  Utility_Relocation_Arrow_6565
#   Utility Relocated                       other      ArcGISFeatureLayer  N2_UtilityPoint_Existing_4633
#   Utility Existing                        other      ArcGISFeatureLayer  N2_UtilityPoint_Existing_1902
#   Chainage                                HOSTED     ArcGISFeatureLayer  7e1812db542a4261b73787dfe5a5d438
#   CenterLine                              HOSTED     ArcGISFeatureLayer  7e1812db542a4261b73787dfe5a5d438
#
#
# TBM_Assembly
# ----------------------------------------------------------------------------------------------------
#   Station                                 HOSTED     ArcGISFeatureLayer  4f155bc22b4d461fa3c09ea256b1e3a4
#   Construction Boundary                   HOSTED     ArcGISFeatureLayer  4f155bc22b4d461fa3c09ea256b1e3a4
#   TBM_Alignment                           HOSTED     ArcGISFeatureLayer  667c227b767a4dd691a53f2a6cfcd24a
#
#
# Status for Relocation (ISF)_N2
# ----------------------------------------------------------------------------------------------------
#   Pier No                                 HOSTED     ArcGISFeatureLayer  133a8266943247ffaaf44b41f94d08f4
#   Chainage                                HOSTED     ArcGISFeatureLayer  7e1812db542a4261b73787dfe5a5d438
#   Alignment CenterLine                    HOSTED     ArcGISFeatureLayer  7e1812db542a4261b73787dfe5a5d438
#   Free and Clear                          HOSTED     ArcGISFeatureLayer  e5f46f9a7a3a44879ad0420ccff3f33e
#   Priority Lots                           HOSTED     ArcGISFeatureLayer  3e31d434ec9a4e7b978dec0d99059ee5
#   Structure Boundary                      HOSTED     ArcGISFeatureLayer  442de7a0e25d4eaa8b6b3fe2e3b68262
#   Station_N2                              HOSTED     ArcGISFeatureLayer  36f7d5fd1a5c444fbfcb2bf2897c3993
#   NSCR_Ex PROW                            HOSTED     ArcGISFeatureLayer  878c49e145b34f269947f8584cd3512c
#   Status for Relocation                   HOSTED     ArcGISFeatureLayer  c12eddbc2bb346208e4af16048a43947
#   Status of Structure                     HOSTED     ArcGISFeatureLayer  442de7a0e25d4eaa8b6b3fe2e3b68262
#   Status of Land Acquisition              HOSTED     ArcGISFeatureLayer  3e31d434ec9a4e7b978dec0d99059ee5
#   Lot Boundary                            HOSTED     ArcGISFeatureLayer  3e31d434ec9a4e7b978dec0d99059ee5
#   Station_Box_N2                          HOSTED     ArcGISFeatureLayer  9ccf8eadda704960b3559c697ce1f0c9
#   Municipality (one boundary)             HOSTED     ArcGISFeatureLayer  fcb7c73a624e40d9ac12cea319427ff8
#   Barangay (one boundary)                 HOSTED     ArcGISFeatureLayer  fcb7c73a624e40d9ac12cea319427ff8
#
#
# SC_Landlocked
# ----------------------------------------------------------------------------------------------------
#   AffectedAreasLandlockedSC               HOSTED     ArcGISFeatureLayer  8b586731718d4415bfcc725e25644af9
#   PotentialAccessSC                       HOSTED     ArcGISFeatureLayer  9fefc1af5d7a4c289734643b4cc00812
#   SC_PotentialLandlocked_Point            HOSTED     ArcGISFeatureLayer  581fbb2ee7b7438abbfbf6016316148c
#   SC_PotentialLandlocked_Polygon          HOSTED     ArcGISFeatureLayer  39b04a5f445c4768807d676f8a6fdf0b
#   SC_Centerline                           HOSTED     ArcGISFeatureLayer  6b070349c5f74a119cf33a8a925dee95
#   SC_Chainage                             HOSTED     ArcGISFeatureLayer  6b070349c5f74a119cf33a8a925dee95
#   SC_Parcellary                           HOSTED     ArcGISFeatureLayer  6b070349c5f74a119cf33a8a925dee95
#   SC_PROW                                 HOSTED     ArcGISFeatureLayer  6b070349c5f74a119cf33a8a925dee95
#   Structure_SC                            HOSTED     ArcGISFeatureLayer  cc7d0ef7e1144144b71d06dbf2c1ae9b
#
#
# Status of Land and Structure Acquisition (N2)
# ----------------------------------------------------------------------------------------------------
#   Pier Head/Column                        HOSTED     ArcGISFeatureLayer  d6a26319b66141e5861d4662c009b961
#   Pier No                                 HOSTED     ArcGISFeatureLayer  133a8266943247ffaaf44b41f94d08f4
#   Chainage                                HOSTED     ArcGISFeatureLayer  7e1812db542a4261b73787dfe5a5d438
#   Alignment CenterLine                    HOSTED     ArcGISFeatureLayer  7e1812db542a4261b73787dfe5a5d438
#   Free and Clear                          HOSTED     ArcGISFeatureLayer  e5f46f9a7a3a44879ad0420ccff3f33e
#   Priority Lots                           HOSTED     ArcGISFeatureLayer  3e31d434ec9a4e7b978dec0d99059ee5
#   Structure Boundary                      HOSTED     ArcGISFeatureLayer  442de7a0e25d4eaa8b6b3fe2e3b68262
#   Station_N2                              HOSTED     ArcGISFeatureLayer  36f7d5fd1a5c444fbfcb2bf2897c3993
#   NSCR_Ex PROW                            HOSTED     ArcGISFeatureLayer  878c49e145b34f269947f8584cd3512c
#   Structure (NLO/LO)                      HOSTED     ArcGISFeatureLayer  9c00382e131847288ee9c02f09badcf1
#   Status for Relocation (Occupancy)       HOSTED     ArcGISFeatureLayer  c12eddbc2bb346208e4af16048a43947
#   Structure (Mode of Acquisition)         other      ArcGISFeatureLayer  176549daf34-layer-2_3274
#   Status of Structure                     HOSTED     ArcGISFeatureLayer  442de7a0e25d4eaa8b6b3fe2e3b68262
#   Status of Land Acquisition              HOSTED     ArcGISFeatureLayer  3e31d434ec9a4e7b978dec0d99059ee5
#   Land (Mode of Acquisition)              other      ArcGISFeatureLayer  Parcellary_compiled_N2_6966_9609
#   Lot Boundary                            HOSTED     ArcGISFeatureLayer  3e31d434ec9a4e7b978dec0d99059ee5
#   Station_Box                             HOSTED     ArcGISFeatureLayer  f9f53223e41e4006b76484c04a2b9916
#   Municipality (one boundary)             HOSTED     ArcGISFeatureLayer  fcb7c73a624e40d9ac12cea319427ff8
#   Barangay (one boundary)                 HOSTED     ArcGISFeatureLayer  fcb7c73a624e40d9ac12cea319427ff8
#
#
# Status of Land and Structure Acquisition (SC)
# ----------------------------------------------------------------------------------------------------
#   Chainage                                HOSTED     ArcGISFeatureLayer  9c6026c7b748428796c35709ed4d560f
#   Centerline                              HOSTED     ArcGISFeatureLayer  9c6026c7b748428796c35709ed4d560f
#   SC_Free_and_Clear                       HOSTED     ArcGISFeatureLayer  11a01113679a43cda817b3ddd6c60ea1
#   Priority Lots                           other      ArcGISFeatureLayer  Parcellary_Structure_SC_2189_7069_3147
#   Station SC                              HOSTED     ArcGISFeatureLayer  16ed67786ee846018169fa00da3bc586
#   NSCR_Ex PROW                            HOSTED     ArcGISFeatureLayer  878c49e145b34f269947f8584cd3512c
#   Status for Relocation                   HOSTED     ArcGISFeatureLayer  37485cc08f924ffb84a673469bdcf7a8
#   Status of Structure                     HOSTED     ArcGISFeatureLayer  cc7d0ef7e1144144b71d06dbf2c1ae9b
#   Status of Land Acquisition              HOSTED     ArcGISFeatureLayer  37485cc08f924ffb84a673469bdcf7a8
#   Lot Boundary                            other      ArcGISFeatureLayer  Parcellary_Structure_SC_2189_7069
#   Structure Boundary                      other      ArcGISFeatureLayer  Structure_SC_4197_7998
#   Station Box                             HOSTED     ArcGISFeatureLayer  9c6026c7b748428796c35709ed4d560f
#
#
# 00-Pre-Construction Status (MMSP)
# ----------------------------------------------------------------------------------------------------
#   Stations                                HOSTED     ArcGISFeatureLayer  4f155bc22b4d461fa3c09ea256b1e3a4
#   Construction Boundary                   HOSTED     ArcGISFeatureLayer  4f155bc22b4d461fa3c09ea256b1e3a4
#   PO Section                              HOSTED     ArcGISFeatureLayer  4f155bc22b4d461fa3c09ea256b1e3a4
#   Creek Diversion                         HOSTED     ArcGISFeatureLayer  4f155bc22b4d461fa3c09ea256b1e3a4
#   Depot Building                          HOSTED     ArcGISFeatureLayer  4f155bc22b4d461fa3c09ea256b1e3a4
#   BSS Building                            HOSTED     ArcGISFeatureLayer  4f155bc22b4d461fa3c09ea256b1e3a4
#   East Valenzuela                         HOSTED     ArcGISFeatureLayer  4f155bc22b4d461fa3c09ea256b1e3a4
#   NNC_Construction_Boundary (Senate)      HOSTED     ArcGISFeatureLayer  4f155bc22b4d461fa3c09ea256b1e3a4
#   Drainage Pipe                           HOSTED     ArcGISFeatureLayer  4f155bc22b4d461fa3c09ea256b1e3a4
#   Creek                                   HOSTED     ArcGISFeatureLayer  4f155bc22b4d461fa3c09ea256b1e3a4
#   Utility Line (Relocated)                other      ArcGISFeatureLayer  Utility_Relocation_Dataset_1063_6812
#   Utility Line (Demolished)               HOSTED     ArcGISFeatureLayer  17c3a72249a141acba0f1af68e67527a
#   Utility Point (Relocated)               other      ArcGISFeatureLayer  Utility_Relocation_Dataset_9277_2060
#   Utility Point (Demolished)              HOSTED     ArcGISFeatureLayer  17c3a72249a141acba0f1af68e67527a
#   Trees (Cut/Earthballed)                 HOSTED     ArcGISFeatureLayer  96fbd3f01cf94f6f9c2b2c73a940d595
#   Trees (Paid)                            other      ArcGISFeatureLayer  Tree_Cutting_and_Compensation_Dataset_4454_4968
#   Structure (HandOver)                    other      ArcGISFeatureLayer  Status_of_Land_Acquisition_3241_6879_616
#   Structure (Paid)                        other      ArcGISFeatureLayer  Status_of_Land_Acquisition_3241_6879
#   LA (HandOver)                           other      ArcGISFeatureLayer  Status_of_Land_Acquisition_3241_3665
#   LA (Paid)                               HOSTED     ArcGISFeatureLayer  4f155bc22b4d461fa3c09ea256b1e3a4
#
#
# UAV Checklist
# ----------------------------------------------------------------------------------------------------
#   UAV Checklist                           HOSTED     ArcGISFeatureLayer  0f5de4339a5e4cfd964c84c30d41c9e0

# %%
# Use helper functions to return a list of the unique itemId values consumed in each web map
for wm in source_admin_inventory['Web Map']:
    print(f"{wm.title}\n{'-'*80}")
    for item_id in get_layer_item_ids(wm):
        print(f"{' '*2}{item_id}")
    print("\n")
# Out:
# NSCR-Ex Stations
# --------------------------------------------------------------------------------
#   4cf42c35bf024eda9e926b273fdbaa05
#   fc0c7e4745a247a8b9893f5311754181
#   d7f2148cf56f45428db7147f116fce9a
#   36f7d5fd1a5c444fbfcb2bf2897c3993
#   d0f7efbb44af4285b52df5a34695c669
#   a22c1df2832b4088a00f3d7f566ede88
#
#
# Status of Tree Cutting and Conservation (N2)
# --------------------------------------------------------------------------------
#   878c49e145b34f269947f8584cd3512c
#   515c18f3b5204f9b9d7d047e30a94b2f
#   16ed67786ee846018169fa00da3bc586
#
#
# N2 Parcellary
# --------------------------------------------------------------------------------
#   d0f7efbb44af4285b52df5a34695c669
#   0e77ef47f9e240cabe4baf5673e75986
#   76203e105a3a4ec6a31fa119db680c36
#
#
# SES Validation Survey Dispatcher Map
# --------------------------------------------------------------------------------
#   483b6be6b5cb4f349984b3ec2f5cbb98
#
#
# SES Validation Tool for NLO
# --------------------------------------------------------------------------------
#   ff6171de487d4e5a80745f5841a116f7
#
#
# SC RAP - SCM and Appraisal
# --------------------------------------------------------------------------------
#   3ca299657dfa4278aa399822079669e8
#
#
# TEST_clone_to_PORTAL
# --------------------------------------------------------------------------------
#   8bff96a629b14f3ca94060613262853c
#
#
# SES Validation Survey
# --------------------------------------------------------------------------------
#   483b6be6b5cb4f349984b3ec2f5cbb98
#
#
# Status of Relocation (ISF)_N2
# --------------------------------------------------------------------------------
#   d6a26319b66141e5861d4662c009b961
#   133a8266943247ffaaf44b41f94d08f4
#   7e1812db542a4261b73787dfe5a5d438
#   e5f46f9a7a3a44879ad0420ccff3f33e
#   3e31d434ec9a4e7b978dec0d99059ee5
#   414bf052e9344cd58125adbe10d2520d
#   c12eddbc2bb346208e4af16048a43947
#   442de7a0e25d4eaa8b6b3fe2e3b68262
#   36f7d5fd1a5c444fbfcb2bf2897c3993
#   878c49e145b34f269947f8584cd3512c
#   9c00382e131847288ee9c02f09badcf1
#   f9f53223e41e4006b76484c04a2b9916
#   fcb7c73a624e40d9ac12cea319427ff8
#
#
# Status of Land Acquisition (MMSP)
# --------------------------------------------------------------------------------
#   4f155bc22b4d461fa3c09ea256b1e3a4
#
#
# N2_LA_basemap
# --------------------------------------------------------------------------------
#   7e1812db542a4261b73787dfe5a5d438
#   e5f46f9a7a3a44879ad0420ccff3f33e
#   3e31d434ec9a4e7b978dec0d99059ee5
#   442de7a0e25d4eaa8b6b3fe2e3b68262
#   36f7d5fd1a5c444fbfcb2bf2897c3993
#   878c49e145b34f269947f8584cd3512c
#   c12eddbc2bb346208e4af16048a43947
#   9ccf8eadda704960b3559c697ce1f0c9
#
#
# SES Validation for Training Tool
# --------------------------------------------------------------------------------
#   94af0fd8a8ff46b5bfb60b4924efd8f5
#
#
# CPN01_landlocked
# --------------------------------------------------------------------------------
#   7e1812db542a4261b73787dfe5a5d438
#   ca3df3508a2f4c89a79a158a8397ba9b
#   055e66e9d65442fb959aa08874200d5a
#   878c49e145b34f269947f8584cd3512c
#   3aeb3d980fdf4e32893ee97c4ebe45b2
#
#
# 00-Land and Structure (MMSP)
# --------------------------------------------------------------------------------
#   4f155bc22b4d461fa3c09ea256b1e3a4
#
#
# SC_Landlocked_Street
# --------------------------------------------------------------------------------
#   8b586731718d4415bfcc725e25644af9
#   9fefc1af5d7a4c289734643b4cc00812
#   581fbb2ee7b7438abbfbf6016316148c
#   39b04a5f445c4768807d676f8a6fdf0b
#   6b070349c5f74a119cf33a8a925dee95
#   cc7d0ef7e1144144b71d06dbf2c1ae9b
#
#
# Status of Land Acquisition (MMSP)-Priority1
# --------------------------------------------------------------------------------
#   4f155bc22b4d461fa3c09ea256b1e3a4
#
#
# SC Contactless Attendance
# --------------------------------------------------------------------------------
#   3646d834e6ba4b19b0d7193e9ca97013
#
#
# Status of Tree Compensation_N2
# --------------------------------------------------------------------------------
#   878c49e145b34f269947f8584cd3512c
#   515c18f3b5204f9b9d7d047e30a94b2f
#   16ed67786ee846018169fa00da3bc586
#
#
# Pre-Construction Status (N2)
# --------------------------------------------------------------------------------
#   4c889516500442dfb6692315ea474ded
#   515c18f3b5204f9b9d7d047e30a94b2f
#   414bf052e9344cd58125adbe10d2520d
#   442de7a0e25d4eaa8b6b3fe2e3b68262
#   3e31d434ec9a4e7b978dec0d99059ee5
#   d6a26319b66141e5861d4662c009b961
#   f9f53223e41e4006b76484c04a2b9916
#   133a8266943247ffaaf44b41f94d08f4
#   7e1812db542a4261b73787dfe5a5d438
#   e5f46f9a7a3a44879ad0420ccff3f33e
#   36f7d5fd1a5c444fbfcb2bf2897c3993
#   878c49e145b34f269947f8584cd3512c
#   9c00382e131847288ee9c02f09badcf1
#   c12eddbc2bb346208e4af16048a43947
#   fcb7c73a624e40d9ac12cea319427ff8
#
#
# Survey123_BanlicTrial
# --------------------------------------------------------------------------------
#   29ff3fd32cab4f5795dc81bab44e96ee
#
#
# Utility Relocation (N2)
# --------------------------------------------------------------------------------
#   7e1812db542a4261b73787dfe5a5d438
#
#
# TBM_Assembly
# --------------------------------------------------------------------------------
#   4f155bc22b4d461fa3c09ea256b1e3a4
#   667c227b767a4dd691a53f2a6cfcd24a
#
#
# Status for Relocation (ISF)_N2
# --------------------------------------------------------------------------------
#   133a8266943247ffaaf44b41f94d08f4
#   7e1812db542a4261b73787dfe5a5d438
#   e5f46f9a7a3a44879ad0420ccff3f33e
#   3e31d434ec9a4e7b978dec0d99059ee5
#   442de7a0e25d4eaa8b6b3fe2e3b68262
#   36f7d5fd1a5c444fbfcb2bf2897c3993
#   878c49e145b34f269947f8584cd3512c
#   c12eddbc2bb346208e4af16048a43947
#   9ccf8eadda704960b3559c697ce1f0c9
#   fcb7c73a624e40d9ac12cea319427ff8
#
#
# SC_Landlocked
# --------------------------------------------------------------------------------
#   8b586731718d4415bfcc725e25644af9
#   9fefc1af5d7a4c289734643b4cc00812
#   581fbb2ee7b7438abbfbf6016316148c
#   39b04a5f445c4768807d676f8a6fdf0b
#   6b070349c5f74a119cf33a8a925dee95
#   cc7d0ef7e1144144b71d06dbf2c1ae9b
#
#
# Status of Land and Structure Acquisition (N2)
# --------------------------------------------------------------------------------
#   d6a26319b66141e5861d4662c009b961
#   133a8266943247ffaaf44b41f94d08f4
#   7e1812db542a4261b73787dfe5a5d438
#   e5f46f9a7a3a44879ad0420ccff3f33e
#   3e31d434ec9a4e7b978dec0d99059ee5
#   442de7a0e25d4eaa8b6b3fe2e3b68262
#   36f7d5fd1a5c444fbfcb2bf2897c3993
#   878c49e145b34f269947f8584cd3512c
#   9c00382e131847288ee9c02f09badcf1
#   c12eddbc2bb346208e4af16048a43947
#   f9f53223e41e4006b76484c04a2b9916
#   fcb7c73a624e40d9ac12cea319427ff8
#
#
# Status of Land and Structure Acquisition (SC)
# --------------------------------------------------------------------------------
#   9c6026c7b748428796c35709ed4d560f
#   11a01113679a43cda817b3ddd6c60ea1
#   37485cc08f924ffb84a673469bdcf7a8
#   16ed67786ee846018169fa00da3bc586
#   878c49e145b34f269947f8584cd3512c
#   cc7d0ef7e1144144b71d06dbf2c1ae9b
#
#
# 00-Pre-Construction Status (MMSP)
# --------------------------------------------------------------------------------
#   4f155bc22b4d461fa3c09ea256b1e3a4
#   17c3a72249a141acba0f1af68e67527a
#   96fbd3f01cf94f6f9c2b2c73a940d595
#
#
# UAV Checklist
# --------------------------------------------------------------------------------
#   0f5de4339a5e4cfd964c84c30d41c9e0

# %%
# Use helper functions to return a list of the unique itemId values consumed in each web map
for wm in source_admin_inventory['Web Map']:
    wm_obj = WebMap(wm)
    if wm_obj.item.title == "Test_Dataset_Clone_to_Portal":
        print(f"{wm.title}\n{'-'*80}")
        for item_id in get_layer_item_ids(wm):
            print(f"{' '*2}{item_id}")
        print("\n")
        print(wm_obj.item.ownerFolder)
    else:
        pass
# Out:
# Test_Dataset_Clone_to_Portal
# --------------------------------------------------------------------------------
#   99341ac1982b48f697af94b13a774f69
#
#
# 53fb73f7101b4d49aa8b36c2d21260ad

# %%
# Choose a specific Web Map (not clone all the web maps)
# Make sure that all the feature layers are saved in a folder (I am not sure how feature layers saved in a root folder can?: 
# folder name is '')
wm_map = {}
for wm in source_admin_inventory['Web Map']:
    wm_obj = WebMap(wm)
    if wm_obj.item.title == "Test_Dataset_Clone_to_Portal":
        print(f"{wm_obj.item.title}\n{'-'*50}")
        if wm_obj.item.ownerFolder:
            folder_name = [f['title'] for f in source.users.me.folders
                           if f['id'] == wm_obj.item.ownerFolder][0]
        try:
            print(f"...cloning {wm_obj.item.title}")
            cloned_wm = target.content.clone_items(items=[wm_obj.item], folder=folder_name)
            wm_map[wm.id] = cloned_wm[0].id
            print(f"...completed")
            print(f"\n")
        except Exception as e:
            print(f"....failed to clone {wm_obj.item.title}")
            print(str(e))
            print(f"\n")
    else:
        pass
# Out:
# Test_Dataset_Clone_to_Portal
# --------------------------------------------------
# ...cloning Test_Dataset_Clone_to_Portal
# ...completed

# %%
# Clone web maps
## If item ID exists in the web maps, it will use ones in target. If item ID does not exist, it will clone the item.
## For non-hosted items, it will recreate those items in the resulting web map.
wm_map = {}
for wm in source_admin_inventory['Web Map']:
    wm_obj = WebMap(wm)
    print(f"{wm_obj.item.title}\n{'-'*50}")
    if wm_obj.item.ownerFolder:
        folder_name = [f['title'] for f in source.users.me.folders 
                       if f['id'] == wm_obj.item.ownerFolder][0]
        try:
            print(f"...cloning {wm_obj.item.title}")
            cloned_wm = target.content.clone_items(items=[wm_obj.item], 
                                              folder=folder_name)          
            wm_map[wm.id] = cloned_wm[0].id
            print(f"...completed")
            print(f"\n")
        except Exception as e:
            print(f"....failed to clone {wm_obj.item.title}")
            print(str(e))
            print(f"\n")
# Out:
# 01-Status_Properties for Acquisition
# --------------------------------------------------
# ...cloning 01-Status_Properties for Acquisition
# ...completed
#
#
# 01-NVS Simplified-Priority1
# --------------------------------------------------
# ...cloning 01-NVS Simplified-Priority1
# ...completed
#
#
# 01-NVS Simplified
# --------------------------------------------------
# ...cloning 01-NVS Simplified
# ...completed
#
#
# Payment Processing and Expropriation Cases
# --------------------------------------------------
# ...cloning Payment Processing and Expropriation Cases
# ....failed to clone Payment Processing and Expropriation Cases
# list index out of range
#
#
# TBM_Segment
# --------------------------------------------------
# ...cloning TBM_Segment
# ....failed to clone TBM_Segment
# list index out of range
#
#
# BingMaps
# --------------------------------------------------
# World Street Map Night No Buildings
# --------------------------------------------------
# OtB Preparation and OtB Delivered
# --------------------------------------------------
# ...cloning OtB Preparation and OtB Delivered
# ....failed to clone OtB Preparation and OtB Delivered
# list index out of range
#
#
# TBM_Manufacture
# --------------------------------------------------
# ...cloning TBM_Manufacture
# ....failed to clone TBM_Manufacture
# list index out of range
#
#
# 01-Status_NVS2_PaymentProcessing
# --------------------------------------------------
# ...cloning 01-Status_NVS2_PaymentProcessing
# ...completed
#
#
# Status of OtB and OtC
# --------------------------------------------------
# ...cloning Status of OtB and OtC
# ....failed to clone Status of OtB and OtC
# list index out of range
#
#
# Rail Sector Maps
# --------------------------------------------------
# TBM_Location
# --------------------------------------------------
# ...cloning TBM_Location
# ....failed to clone TBM_Location
# list index out of range
#
#
# 01-Status_NVS
# --------------------------------------------------
# ...cloning 01-Status_NVS
# ...completed

# %%
# Examine the resulting Web Map items in the target
target_admin_inventory = get_user_items(target.users.me, target)

# %%
active_gis = target

# %%
for wm in target_admin_inventory['Web Map']:
    print_webmap_inventory(wm)
# Out:
# Sample_DeleteLater
# ----------------------------------------------------------------------------------------------------
#   MMSP_Alignment - MMSP_Station           other      ArcGISFeatureLayer  MMSP_Alignment_9167
#   MMSP_Alignment                          other      ArcGISFeatureLayer  MMSP_Alignment_1002
#   EVS Boundary                            other      ArcGISFeatureLayer  EVS_Boundary_1215
#
#
# BingMaps
# ----------------------------------------------------------------------------------------------------
#
#
# World Street Map Night No Buildings
# ----------------------------------------------------------------------------------------------------
#
#
# Tree Cutting and Conservation
# ----------------------------------------------------------------------------------------------------
#   PROW                                    HOSTED     ArcGISFeatureLayer  7402e136afb942bd8cb3540b3d11ea78
#   Conservation                            other      ArcGISFeatureLayer  adf0b004fd6744ac9832a795a146adf1_8390
#   Status of Tree Cutting                  HOSTED     ArcGISFeatureLayer  7402e136afb942bd8cb3540b3d11ea78
#   Structure Boundary                      HOSTED     ArcGISFeatureLayer  7402e136afb942bd8cb3540b3d11ea78
#   Lot Boundary                            HOSTED     ArcGISFeatureLayer  7402e136afb942bd8cb3540b3d11ea78
#   PNR                                     HOSTED     ArcGISFeatureLayer  7402e136afb942bd8cb3540b3d11ea78
#   Station                                 HOSTED     ArcGISFeatureLayer  7402e136afb942bd8cb3540b3d11ea78
#   Community (No Buildings)                other      VectorTileLayer     24f71d94aea044a3990c19d11491c5bd
#
#
# TBM Assembly
# ----------------------------------------------------------------------------------------------------
#   Stations                                other      ArcGISFeatureLayer  Stations_3646
#   Construction Boundary                   other      ArcGISFeatureLayer  Land_Acquisition_mmsp_WFL1_4525
#   TBM Alignment                           HOSTED     ArcGISFeatureLayer  7a5b88d46d1d4bc08e2a9d3567750875
#
#
# Land_Acquisition (MMSP)
# ----------------------------------------------------------------------------------------------------
#   Stations                                HOSTED     ArcGISFeatureLayer  86159bef446a4de991365c0b89c2bc4c
#   Drainage                                HOSTED     ArcGISFeatureLayer  86159bef446a4de991365c0b89c2bc4c
#   PO Section                              HOSTED     ArcGISFeatureLayer  86159bef446a4de991365c0b89c2bc4c
#   East Valenzuela                         HOSTED     ArcGISFeatureLayer  86159bef446a4de991365c0b89c2bc4c
#   Construction Boundary                   HOSTED     ArcGISFeatureLayer  86159bef446a4de991365c0b89c2bc4c
#   Creek Diversion                         HOSTED     ArcGISFeatureLayer  86159bef446a4de991365c0b89c2bc4c
#   Creek                                   HOSTED     ArcGISFeatureLayer  86159bef446a4de991365c0b89c2bc4c
#   Depot Building                          HOSTED     ArcGISFeatureLayer  86159bef446a4de991365c0b89c2bc4c
#   Priority                                HOSTED     ArcGISFeatureLayer  86159bef446a4de991365c0b89c2bc4c
#   BSS Building                            HOSTED     ArcGISFeatureLayer  86159bef446a4de991365c0b89c2bc4c
#   Status of Land Acquisition              HOSTED     ArcGISFeatureLayer  86159bef446a4de991365c0b89c2bc4c
#   Lot Boundary                            HOSTED     ArcGISFeatureLayer  86159bef446a4de991365c0b89c2bc4c
#   BSS boundary                            HOSTED     ArcGISFeatureLayer  86159bef446a4de991365c0b89c2bc4c
#   Construction Boundary (NA)              HOSTED     ArcGISFeatureLayer  86159bef446a4de991365c0b89c2bc4c
#   NNC_Construction_Boundary (Senate)      HOSTED     ArcGISFeatureLayer  86159bef446a4de991365c0b89c2bc4c
#   Segment_8.2 (DPWH)                      HOSTED     ArcGISFeatureLayer  86159bef446a4de991365c0b89c2bc4c
#   Priority                                HOSTED     ArcGISFeatureLayer  86159bef446a4de991365c0b89c2bc4c
#   Handed OVer                             HOSTED     ArcGISFeatureLayer  86159bef446a4de991365c0b89c2bc4c
#   Expropriation Cases                     HOSTED     ArcGISFeatureLayer  86159bef446a4de991365c0b89c2bc4c
#   Handed Over                             HOSTED     ArcGISFeatureLayer  86159bef446a4de991365c0b89c2bc4c
#   OtB Preparation                         HOSTED     ArcGISFeatureLayer  86159bef446a4de991365c0b89c2bc4c
#   Expropriation Cases                     HOSTED     ArcGISFeatureLayer  86159bef446a4de991365c0b89c2bc4c
#   Government Property                     HOSTED     ArcGISFeatureLayer  86159bef446a4de991365c0b89c2bc4c
#   For Lot Count                           HOSTED     ArcGISFeatureLayer  86159bef446a4de991365c0b89c2bc4c
#   Hand Over Schedule                      HOSTED     ArcGISFeatureLayer  86159bef446a4de991365c0b89c2bc4c
#   Target_Plan_for_Map_Series              HOSTED     ArcGISFeatureLayer  86159bef446a4de991365c0b89c2bc4c
#   Target_Plan_Schedule                    HOSTED     ArcGISFeatureLayer  86159bef446a4de991365c0b89c2bc4c
#   EVS Parcellary                          HOSTED     ArcGISFeatureLayer  86159bef446a4de991365c0b89c2bc4c
#   Community (No Buildings)                other      VectorTileLayer     aecf8596f20345ec90b7c732e1b77175
#
#
# Construction Boundary(copy)_DeleteLater
# ----------------------------------------------------------------------------------------------------
#   Excavation_Spot                         other      ArcGISFeatureLayer  Excavation_Spot_1632
#   Construction Boundary (copy)            other      ArcGISFeatureLayer  Land_Acquisition_mmsp_WFL1_3440
#
#
# Rail Sector Maps
# ----------------------------------------------------------------------------------------------------
#   NSCR-Ex (N2)                            other      ArcGISFeatureLayer  NSCR_Ex_N2_Alignment_8587
#   NSCR-Ex (SC)                            other      ArcGISFeatureLayer  NSCR_Ex_SC_Alignment_2438
#   MMSP                                    other      ArcGISFeatureLayer  MMSP_Alignment_2442
#   NSTren (N1)                             other      ArcGISFeatureLayer  NSTren_Alignment_8479
#   NSCR-Ex (N2)                            other      ArcGISFeatureLayer  NSCR_Ex_N2_Alignment_6850
#   NSCR-Ex (SC)                            other      ArcGISFeatureLayer  NSCR_Ex_SC_Alignment_847
#   MMSP                                    other      ArcGISFeatureLayer  MMSP_Alignment_4875
#   NSTren (N1)                             other      ArcGISFeatureLayer  NSTren_Alignment_3606
#
#
# Tree Compensation
# ----------------------------------------------------------------------------------------------------
#   PROW                                    HOSTED     ArcGISFeatureLayer  7402e136afb942bd8cb3540b3d11ea78
#   Tree Compensation                       HOSTED     ArcGISFeatureLayer  7402e136afb942bd8cb3540b3d11ea78
#   Structure Boundary                      HOSTED     ArcGISFeatureLayer  7402e136afb942bd8cb3540b3d11ea78
#   Lot Boundary                            HOSTED     ArcGISFeatureLayer  7402e136afb942bd8cb3540b3d11ea78
#   PNR                                     HOSTED     ArcGISFeatureLayer  7402e136afb942bd8cb3540b3d11ea78
#   Station                                 HOSTED     ArcGISFeatureLayer  7402e136afb942bd8cb3540b3d11ea78
#
#
# Land_Acquisition-priority1 (MMSP)
# ----------------------------------------------------------------------------------------------------
#   Stations                                HOSTED     ArcGISFeatureLayer  86159bef446a4de991365c0b89c2bc4c
#   Drainage                                HOSTED     ArcGISFeatureLayer  86159bef446a4de991365c0b89c2bc4c
#   PO Section                              HOSTED     ArcGISFeatureLayer  86159bef446a4de991365c0b89c2bc4c
#   East Valenzuela                         HOSTED     ArcGISFeatureLayer  86159bef446a4de991365c0b89c2bc4c
#   Construction Boundary                   HOSTED     ArcGISFeatureLayer  86159bef446a4de991365c0b89c2bc4c
#   Creek Diversion                         HOSTED     ArcGISFeatureLayer  86159bef446a4de991365c0b89c2bc4c
#   Creek                                   HOSTED     ArcGISFeatureLayer  86159bef446a4de991365c0b89c2bc4c
#   Depot Building                          HOSTED     ArcGISFeatureLayer  86159bef446a4de991365c0b89c2bc4c
#   Priority                                HOSTED     ArcGISFeatureLayer  86159bef446a4de991365c0b89c2bc4c
#   Priority                                HOSTED     ArcGISFeatureLayer  86159bef446a4de991365c0b89c2bc4c
#   BSS Building                            HOSTED     ArcGISFeatureLayer  86159bef446a4de991365c0b89c2bc4c
#   Status of Land Acquisition              HOSTED     ArcGISFeatureLayer  86159bef446a4de991365c0b89c2bc4c
#   Lot Boundary                            HOSTED     ArcGISFeatureLayer  86159bef446a4de991365c0b89c2bc4c
#   BSS boundary                            HOSTED     ArcGISFeatureLayer  86159bef446a4de991365c0b89c2bc4c
#   Construction Boundary (NA)              HOSTED     ArcGISFeatureLayer  86159bef446a4de991365c0b89c2bc4c
#   NNC_Construction_Boundary (Senate)      HOSTED     ArcGISFeatureLayer  86159bef446a4de991365c0b89c2bc4c
#   Segment_8.2 (DPWH)                      HOSTED     ArcGISFeatureLayer  86159bef446a4de991365c0b89c2bc4c
#   Handed OVer                             HOSTED     ArcGISFeatureLayer  86159bef446a4de991365c0b89c2bc4c
#   Expropriation Cases                     HOSTED     ArcGISFeatureLayer  86159bef446a4de991365c0b89c2bc4c
#   Handed Over                             HOSTED     ArcGISFeatureLayer  86159bef446a4de991365c0b89c2bc4c
#   OtB Preparation                         HOSTED     ArcGISFeatureLayer  86159bef446a4de991365c0b89c2bc4c
#   Expropriation Cases                     HOSTED     ArcGISFeatureLayer  86159bef446a4de991365c0b89c2bc4c
#   Government Property                     HOSTED     ArcGISFeatureLayer  86159bef446a4de991365c0b89c2bc4c
#   For Lot Count                           HOSTED     ArcGISFeatureLayer  86159bef446a4de991365c0b89c2bc4c
#   Hand Over Schedule                      HOSTED     ArcGISFeatureLayer  86159bef446a4de991365c0b89c2bc4c
#   Target_Plan_for_Map_Series              HOSTED     ArcGISFeatureLayer  86159bef446a4de991365c0b89c2bc4c
#   Target_Plan_Schedule                    HOSTED     ArcGISFeatureLayer  86159bef446a4de991365c0b89c2bc4c
#   EVS Parcellary                          HOSTED     ArcGISFeatureLayer  86159bef446a4de991365c0b89c2bc4c
#   Community (No Buildings)                other      VectorTileLayer     aecf8596f20345ec90b7c732e1b77175
#
#
# Land_Acquisition_N2
# ----------------------------------------------------------------------------------------------------
#   PierHead_Column_N2                      other      ArcGISFeatureLayer  PierHead_Column_N2_6414
#   Pier_N2                                 other      ArcGISFeatureLayer  Pier_N2_818
#   Chainage                                other      ArcGISFeatureLayer  Alignment_Datasets_2570
#   Centerline                              other      ArcGISFeatureLayer  Alignment_Datasets_635
#   Free and Clear                          other      ArcGISFeatureLayer  Parcellary_Structure_Datasets_9835
#   Priority Lots                           other      ArcGISFeatureLayer  Parcellary_Structure_Datasets_7264
#   Structure Boundary                      other      ArcGISFeatureLayer  Parcellary_Structure_Datasets_9337
#   Station                                 other      ArcGISFeatureLayer  Alignment_Datasets_8271
#   PROW                                    other      ArcGISFeatureLayer  Alignment_Datasets_2929
#   Structure NLO or LO                     other      ArcGISFeatureLayer  Structure__NLO_LO_9050
#   Status of Relocation (ISF)              other      ArcGISFeatureLayer  Parcellary_Structure_Datasets_2225
#   Status for Relocation (Occupancy)       other      ArcGISFeatureLayer  Parcellary_Structure_Datasets_8941
#   Status of Structure                     other      ArcGISFeatureLayer  Parcellary_Structure_Datasets_9588
#   Status of Land Acquisition              other      ArcGISFeatureLayer  Parcellary_Structure_Datasets_281
#   Lot Boundary                            other      ArcGISFeatureLayer  Parcellary_Structure_Datasets_3345
#   BCDA_PNR                                other      ArcGISFeatureLayer  Parcellary_Structure_Datasets_8499
#   Municipality (one boundary)             HOSTED     ArcGISFeatureLayer  87e3af8726fe4f9a93018ec263e797da
#   Barangay (one boundary)                 HOSTED     ArcGISFeatureLayer  87e3af8726fe4f9a93018ec263e797da
#
#
# TEST_clone_to_PORTAL
# ----------------------------------------------------------------------------------------------------
#   TEST_clone_to_PORTAL                    HOSTED     ArcGISFeatureLayer  cdb9d1127fe44c69a014cc8121206c59

# %%
# Examine wm_map dictionary to see that we indeed have a dictionary mapping that has ids as
# both keys (source web map id) and values (target web map id).
wm_map
# Out:
# {'6a7f73cc5c81441daf09c543bd53ae87': '8554988fe0f44a0989214570a42f9286'}

# %%
# Visually compare our web maps

# %%
# Source web map
source_webmap = WebMap(source.content.get(list(wm_map.keys())[0]))
source_webmap
# Out:
# MapView(hide_mode_switch=True, layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-4ff13ec5-d441-46ea-9660-70dbae8f18d2"><img src=""></img></div>
# <div class="map-html-embed-preview-4ff13ec5-d441-46ea-9660-70dbae8f18d2"></div>

# %%
# Target web map
target_webmap = WebMap(target.content.get(list(wm_map.values())[0]))
target_webmap
# Out:
# MapView(hide_mode_switch=True, layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-fe485251-f4aa-4c5b-8d52-a0e25d99c2ed"><img src=""></img></div>
# <div class="map-html-embed-preview-fe485251-f4aa-4c5b-8d52-a0e25d99c2ed"></div>

# %% [markdown]
# ### ArcGIS Dashboards
#
# Clone Operations Dashboard and associated hosted and other feature services

# %%
ops_dash = source_admin_inventory['Dashboard']
n = 0
for dashn in ops_dash:
    n = n + 1
    print(f"{n}. {dashn.title}")

# %%
ops_dash = source_admin_inventory['Dashboard'][6]
ops_dash
# Out:
# <Item title:"TEST_clone_to_PORTAL" type:Dashboard owner:matsuzakieijinscrex>

# %%
# Out:
# 1. GRM Portal
# 2. Status of Pre-Construction_N2
# 3. SC_Landlocked_Dashboard
# 4. Status of Tree Cutting and Conservation (N2)
# 5. Status of Relocation_ISF (N2) _rev2
# 6. Status of Land Acquisition (MMSP)
# 7. Utility Relocation (N2)
# 8. Status of Tree Inventoried (N2)
# 9. Status of Relocation_ISF (N2) _rev1
# 10. Status of Land Acquisition (MMSP) - compiled
# 11. 00-Pre-Construction Status (N2)
# 12. Pre-Construction Status (MMSP)
# 13. Test_Dataset_Clone_to_Portal
# 14. 00-Status of Land and Structure (MMSP)
# 15. Status of Land Acquisition (MMSP)  - Priority1
# 16. NSCR-Ex Project (GRM Website)
# 17. Sample_DeleteLater
# 18. Status of Land and Structure Acquisition (N2)-rev1
# 19. Status of Tree Compensation_N2
# 20. Status of Land and Structure Acquisition (N2)
# 21. TBM Assembly

# %%
active_gis = source

# %%
# Get Web Map used in the Operations Dashboard
dash_wm = get_dash_wm(ops_dash)[0]
dash_wm
# Out:
# <Item title:"TEST_clone_to_PORTAL" type:Web Map owner:matsuzakieijinscrex>

# %%
WebMap(dash_wm)
# Out:
# MapView(hide_mode_switch=True, layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-9c580eca-b7c3-41c2-8a1d-237e0abd5341"><img src=""></img></div>
# <div class="map-html-embed-preview-9c580eca-b7c3-41c2-8a1d-237e0abd5341"></div>

# %%
dash_wm.id
# Out:
# '0c140f5c9e7548a38e5edd2c04876fe9'

# %%
print_webmap_inventory(dash_wm)
# Out:
# TEST_clone_to_PORTAL
# ----------------------------------------------------------------------------------------------------
#   TEST_clone_to_PORTAL                    HOSTED     ArcGISFeatureLayer  8bff96a629b14f3ca94060613262853c

# %%
# Query the web map object we created to see if this web map id was cloned.
wm_item_mapping = {src_wm:trg_wm for src_wm,trg_wm in wm_map.items()
                   if dash_wm.id == src_wm}
wm_item_mapping
# Out:
# {'0c140f5c9e7548a38e5edd2c04876fe9': '5b99829c31ba4d8d87cc0ae5b3d637ef'}

# %%
# Clone Operations Dashboard
target.content.clone_items(items=[ops_dash],
                           folder="MMSP_preC",
                           item_mapping=wm_item_mapping)
# Out:
# [<Item title:"TEST_clone_to_PORTAL" type:Dashboard owner:matsuzakieiji>]
